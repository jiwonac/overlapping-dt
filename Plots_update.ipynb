# %%
# Import libraries for plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
# Results of experiment 1
x = [5, 10, 20, 30, 40, 50]
classic = [7.533333333333333, 
        17.433333333333334,
        39.333333333333336,
        66.43333333333334,
        110.46666666666667,
        179.43333333333334]
ours = [7.6,
        17.6,
        36.06666666666667,
        55.266666666666666,
        75.26666666666667,
        99.43333333333334]
random = [7.5,
        17.033333333333335,
        40.96666666666667,
        66.86666666666666,
        107.23333333333333,
        175.23333333333332]

# %%
plt.plot(x, classic, label = "classic")
plt.plot(x, ours, label = "ours")
plt.plot(x, random, label = "random")
plt.legend()
plt.xticks(x)
plt.xlabel("group requirements")
plt.ylabel("total cost to meet query")
plt.title("Binary sources, binary groups equi-cost using binary DT algorithm.")
plt.show()

# %%
# Results of experiment 2
x = [5, 10, 20, 30, 40, 50]
classic = [6.6,
        16.233333333333334,
        32.833333333333336,
        56.833333333333336,
        83.43333333333334,
        126.46666666666667]
ours = [7.2, 14.9, 34.7, 60.666666666666664, 92.7, 124.73333333333333]
random = [14.933333333333334,
        35.733333333333334,
        78.6,
        133.4,
        212.8,
        336.26666666666665]

# %%
plt.plot(x, classic, label = "classic")
plt.plot(x, ours, label = "ours")
plt.plot(x, random, label = "random")
plt.legend()
plt.xticks(x)
plt.xlabel("group requirements")
plt.ylabel("total cost to meet query")
plt.title("Binary sources, binary groups skewed-cost using general DT algorithm.")
plt.show()

# %%
# Results of experiment 3
x = [5, 10, 20, 30, 40, 50]
classic = [7.9,
        18.366666666666667,
        44.166666666666664,
        78.2,
        137.6,
        382.56666666666666]
ours = [5.633333333333334,
        11.366666666666667,
        24.433333333333334,
        39.93333333333333,
        59.03333333333333,
        78.0]
random = [6.533333333333333,
        13.7,
        26.933333333333334,
        43.2,
        58.46666666666667,
        74.73333333333333]

# %%
plt.plot(x, classic, label = "classic")
plt.plot(x, ours, label = "ours")
plt.plot(x, random, label = "random")
plt.legend()
plt.xticks(x)
plt.xlabel("group requirements")
plt.ylabel("total cost to meet query")
plt.title("Five sources, binary groups equi-cost using binary DT algorithm.")
plt.show()

# %%
# Results of experiment 4
x = [5, 10, 20, 30, 40, 50]
classic = [9.6, 21.7, 47.0, 70.06666666666666, 102.66666666666667, 133.7]
ours = [10.033333333333333,
        21.125,
        42.766666666666666,
        65.30833333333334,
        92.025,
        116.26666666666667]
random = [8.466666666666667,
        18.266666666666666,
        37.983333333333334,
        60.766666666666666,
        81.08333333333333,
        105.64166666666667]

# %%
plt.plot(x, classic, label = "classic")
plt.plot(x, ours, label = "ours")
plt.plot(x, random, label = "random")
plt.legend()
plt.xticks(x)
plt.ylim([0, 400])
plt.xlabel("group requirements")
plt.ylabel("total cost to meet query")
plt.title("Five sources, binary groups skewed-cost using general DT algorithm.")
plt.show()

# %%
# Results of experiment 5
x = [5, 10, 20, 30, 40, 50]
classic = [14.425,
        37.03333333333333,
        92.75833333333334,
        175.85,
        306.325,
        828.9916666666667]
ours = [15.05, 34.875, 92.5, 159.58333333333334, 248.28333333333333, 344.375]
random = [16.158333333333335,
            38.90833333333333,
            100.3,
            172.55,
            250.9,
            361.40833333333336]

# %%
plt.plot(x, classic, label = "classic")
plt.plot(x, ours, label = "ours")
plt.plot(x, random, label = "random")
plt.legend()
plt.xticks(x)
plt.xlabel("group requirements")
plt.ylabel("total cost to meet query")
plt.title("Five sources, four groups skewed-cost using general DT algorithm.")
plt.show()

# %%
# Results of experiment 6
x = [5, 10, 20, 30, 40, 50]
classic = [12.2,
        30.566666666666666,
        80.6,
        151.23333333333332,
        289.56666666666666,
        770.6666666666666]
ours = [12.066666666666666,
        28.6,
        71.76666666666667,
        118.6,
        180.33333333333334,
        241.76666666666668]
random = [12.5,
        31.566666666666666,
        71.9,
        124.26666666666667,
        178.6,
        275.73333333333335]

# %%
plt.plot(x, classic, label = "classic")
plt.plot(x, ours, label = "ours")
plt.plot(x, random, label = "random")
plt.legend()
plt.xticks(x)
plt.xlabel("group requirements")
plt.ylabel("total cost to meet query")
plt.title("Five sources, four groups equi-cost using general DT algorithm.")
plt.show()

# %%
# Results of experiment 7
x = [5, 10, 20, 30, 40]
classic = [13.2, 37.06666666666667, 94.26666666666667, 179.9, 333.1]
ours = [14.433333333333334,
        37.666666666666664,
        96.23333333333333,
        214.46666666666667,
        379.2]
random = [21.933333333333334, 50.8, 135.46666666666667, 254.8, 826.2]

# %%
plt.plot(x, classic, label = "classic")
plt.plot(x, ours, label = "ours")
plt.plot(x, random, label = "random")
plt.legend()
plt.xticks(x)
plt.xlabel("group requirements")
plt.ylabel("total cost to meet query")
plt.title("Binary sources, 4 groups skewed-cost using general DT algorithm.")
plt.show()

# %%
# Results of experiment 8
x = [5, 10, 20, 30, 40]
classic = [12.433333333333334,
        30.066666666666666,
        79.3,
        158.83333333333334,
        277.96666666666664]
ours = [12.7, 33.4, 82.4, 155.8, 283.53333333333336]
random = [9.7,
            24.266666666666666,
            63.2,
            129.56666666666666,
            434.23333333333335]

# %%
plt.plot(x, classic, label = "classic")
plt.plot(x, ours, label = "ours")
plt.plot(x, random, label = "random")
plt.legend()
plt.xticks(x)
plt.xlabel("group requirements")
plt.ylabel("total cost to meet query")
plt.title("Binary sources, 4 groups equi-cost using general DT algorithm.")
plt.show()
